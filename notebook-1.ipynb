# %%
using Random

# %%
layers_vec = [1,6,1]
L = length(layers_vec)-1
# Out:
# 2

# %%
W = Vector{Matrix{Float64}}(undef, L)
# Out:
# 2-element Vector{Matrix{Float64}}:
#  #undef
#  #undef

# %%
rng::AbstractRNG = Random.default_rng()
W = Vector{Matrix{Float64}}(undef, L)
println(layers_vec)
for l in 1:L
    in_dim = layers_vec[l]
    out_dim = layers_vec[l+1]
    println(layers_vec[l])
    println(layers_vec[l+1])
    println("=")
    W[l] = rand(rng, in_dim, out_dim)
end
# Out:
# [1, 6, 1]
# 1
# 6
# =
# 6
# 1
# =

# %%
W[2]
# Out:
# 6×1 Matrix{Float64}:
#  0.8571724341838739
#  0.6250098381790076
#  0.00960644352554696
#  0.4517737668190359
#  0.05636016487511919
#  0.29005587004973854

# %%
Pairs =
